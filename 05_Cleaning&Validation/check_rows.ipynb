# %% [markdown]
# ## Check NO. of rows in each csv file to validate database row insertion

# %%
import pandas as pd

# %%
csv_files=['categories_data.csv', 'courses_data.csv', 'enrollments_data.csv', 'instructors_data.csv', 'payments_data.csv', 'students_data.csv']

print("Rows in csv file")
for i in csv_files:
    df = pd.read_csv(f"../03_Data/raw/{i}")
    print(f"{i} : {len(df)}")
# Out:
# Rows in csv file
# categories_data.csv : 22
# courses_data.csv : 160
# enrollments_data.csv : 5000
# instructors_data.csv : 45
# payments_data.csv : 5600
# students_data.csv : 1400
